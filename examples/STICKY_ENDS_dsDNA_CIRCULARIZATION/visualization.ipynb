# %%
from oxDNA_analysis_tools.UTILS.RyeReader import describe, get_confs, inbox
from oxDNA_analysis_tools.UTILS.oxview import oxdna_conf, from_path

#initial visualization

#load and inbox
ti, di = describe("generated.top", "generated.dat")
conf = inbox(get_confs(ti,di, 0,1)[0])
# display
obj = oxdna_conf(ti, conf, inbox_settings=["None","None"])
# Out:
# WARNING: The old topology format is depreciated and future tools may not support it.  Please update to the new topology format for future simulations.
# ...

# %%
# post sim

#load and inbox
ti, di = describe("generated.top", "last_conf.dat")
conf = inbox(get_confs(ti,di, 0,1)[0])
# display
obj = oxdna_conf(ti, conf, inbox_settings=["None","None"])
# Out:
# WARNING: The old topology format is depreciated and future tools may not support it.  Please update to the new topology format for future simulations.
# ...
